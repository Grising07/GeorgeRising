# %% [markdown]
# # George Rising
#
# # Cybersecurity
#
# # student email: g.rising2564@student.leedsbeckett.ac.uk
#
# # i am submitting exam paper 3

# %% [markdown]
# in programming i have enjoyed learning various tools, i prefer working in an environment with many people around me. this is because i can look around to get help of others as programming is always easier when working with others. This is because i can get their opinions and ideas on things that maybe i didn't think of. this can speed up the process of programming as i dont have to sit there and think about it by myself for a long time. i feel like it helps me bond with people while i am working out programs because it feels good after completing  challenge together.
# # tools i most enjoy using:
# Logic statements
# While loops
# For loops
# If statement
# logic statement

# %%
time = input("please provide a time>>")
try:
    if int(time)>50.5:
print('slower than standard time')
else:
print('faster than standard time')
# Out:
#   Cell In[45], line 4
#     print('slower than standard time')
#                                       ^
# IndentationError: expected an indented block after 'if' statement on line 3
