# %%
#George Rising

#Cybersecurity

#student email: g.rising2564@student.leedsbeckett.ac.uk

"I am submitting exam paper 3"

# %% [markdown]
# in programming i have enjoyed learning various tools, i prefer working in an environment with many people around me. this is because i can look around to get help of others as programming is always easier when working with others.
